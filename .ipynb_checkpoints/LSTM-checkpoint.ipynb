# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = (15,6)

# %%
data = pd.read_csv('ALL_MONTHS_FINAL.csv')
data = data.iloc[:,1:]
data = data.set_index('period')

# %%
data.index = pd.to_datetime(data.index)

# %%
data = data.drop(['Year','Month','Day','Hour'], axis= 1)

# %%
data = data.resample('D').max()

# %%
AP = data.loc[:,['AP']]
C6 = data.loc[:,['C6']]
CO = data.loc[:,['CO']]
NO = data.loc[:,['NO']]
NO2 = data.loc[:,['NO2']]
NOX = data.loc[:,['NOX']]
O3 = data.loc[:,['O3']]
PM10 = data.loc[:,['PM10']]
PM25 = data.loc[:,['PM25']]
RF = data.loc[:,['RF']]
RH = data.loc[:,['RH']]
RT = data.loc[:,['RT']]
SO2 = data.loc[:,['SO2']]
SR = data.loc[:,['SR']]
TOL = data.loc[:,['TOL']]
WD = data.loc[:,['WD']]
WS = data.loc[:,['WS']]
XYL = data.loc[:,['XYL']]

# %%
AP.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(AP['AP'])

# %%
results.plot()

# %%
AP.shape
# Out:
# (366, 1)

# %%
train = AP.iloc[:359]
test = AP.iloc[359:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
scaled_train
# Out:
# array([[0.77302466],
#        [0.59033719],
#        [0.49622547],
#        [0.2994464 ],
#        [0.27428284],
#        [0.32108707],
#        [0.0367388 ],
#        [0.16909914],
#        [0.2259688 ],
#        [0.22345244],
#        [0.57876195],
#        [0.53900352],
#        [0.50226472],
#        [0.48616004],
#        [0.47005536],
#        [0.41268244],
#        [0.4413689 ],
#        [0.41469552],
#        [0.43985908],
#        [0.5586311 ],
#        [0.69300453],
#        [0.66280825],
#        [0.66834424],
#        [0.63361852],
#        [0.54755913],
#        [0.50427781],
#        [0.52692501],
#        [0.57926522],
#        [0.63714142],
#        [0.63814796],
#        [0.56467036],
#        [0.79063915],
#        [0.59637645],
#        [0.53145445],
#        [0.30397584],
#        [0.26069451],
#        [0.28736789],
#        [0.01912431],
#        [0.03925516],
#        [0.23251132],
#        [0.30850528],
#        [0.54252642],
#        [0.56366381],
#        [0.46703573],
#        [0.47206844],
#        [0.47508807],
#        [0.47206844],
#        [0.50629089],
#        [0.49974836],
#        [0.55208858],
#        [0.5727227 ],
#        [0.53145445],
#        [0.51685959],
#        [0.43281329],
#        [0.38651233],
#        [0.43331656],
#        [0.49370911],
#        [0.52591847],
#        [0.57070961],
#        [0.60493206],
#        [0.7075994 ],
#        [0.56366381],
#        [0.59285355],
#        [0.38198289],
#        [0.24257675],
#        [0.21087066],
#        [0.07196779],
#        [0.0140916 ],
#        [0.26170106],
#        [0.24962255],
#        [0.55561147],
#        [0.59235028],
#        [0.41368898],
#        [0.4710619 ],
#        [0.43633619],
#        [0.37443382],
#        [0.39557121],
#        [0.41670861],
#        [0.42325113],
#        [0.45848012],
#        [0.43935581],
#        [0.31857071],
#        [0.33215903],
#        [0.39959738],
#        [0.4011072 ],
#        [0.42224459],
#        [0.40060393],
#        [0.41670861],
#        [0.43231002],
#        [0.42828384],
#        [0.43180674],
#        [0.72521389],
#        [0.56165073],
#        [0.59486663],
#        [0.32460996],
#        [0.23704076],
#        [0.28334172],
#        [0.13437343],
#        [0.03824862],
#        [0.35933568],
#        [0.28585808],
#        [1.        ],
#        [0.64318067],
#        [0.25264217],
#        [0.23653749],
#        [0.28787116],
#        [0.25616507],
#        [0.24509311],
#        [0.26774031],
#        [0.27025667],
#        [0.31454454],
#        [0.29441369],
#        [0.28787116],
#        [0.21942627],
#        [0.16205335],
#        [0.21439356],
#        [0.28183191],
#        [0.26522396],
#        [0.20785103],
#        [0.24006039],
#        [0.2662305 ],
#        [0.66180171],
#        [0.49068948],
#        [0.44187217],
#        [0.30699547],
#        [0.29038752],
#        [0.28233518],
#        [0.12179165],
#        [0.01811777],
#        [0.37342728],
#        [0.30095622],
#        [0.38802214],
#        [0.59486663],
#        [0.22798188],
#        [0.31806744],
#        [0.32209361],
#        [0.20181178],
#        [0.11122295],
#        [0.0332159 ],
#        [0.03120282],
#        [0.10065425],
#        [0.21992954],
#        [0.26371414],
#        [0.29894313],
#        [0.27679919],
#        [0.24760946],
#        [0.28887771],
#        [0.30246603],
#        [0.31555108],
#        [0.27730247],
#        [0.21741319],
#        [0.27830901],
#        [0.64368395],
#        [0.37795672],
#        [0.40764972],
#        [0.32964268],
#        [0.28032209],
#        [0.24559638],
#        [0.10669351],
#        [0.05737292],
#        [0.38600906],
#        [0.31253145],
#        [0.45546049],
#        [0.58530448],
#        [0.23049824],
#        [0.21741319],
#        [0.14695521],
#        [0.12934071],
#        [0.13688978],
#        [0.16406643],
#        [0.06794162],
#        [0.02868646],
#        [0.07448415],
#        [0.15047811],
#        [0.14141922],
#        [0.10518369],
#        [0.19023654],
#        [0.16507297],
#        [0.06391545],
#        [0.03019628],
#        [0.0910921 ],
#        [0.08253649],
#        [0.66935078],
#        [0.53548062],
#        [0.39355813],
#        [0.33165576],
#        [0.23704076],
#        [0.18369401],
#        [0.12682436],
#        [0.13437343],
#        [0.34373427],
#        [0.3064922 ],
#        [0.57574233],
#        [0.57825868],
#        [0.08152994],
#        [0.12581782],
#        [0.16557625],
#        [0.21439356],
#        [0.30045294],
#        [0.29391042],
#        [0.27730247],
#        [0.2294917 ],
#        [0.17211877],
#        [0.13034726],
#        [0.10216407],
#        [0.1207851 ],
#        [0.14041268],
#        [0.15903372],
#        [0.20231505],
#        [0.21338702],
#        [0.18922999],
#        [0.15953699],
#        [0.19778561],
#        [0.70860594],
#        [0.52440866],
#        [0.33115249],
#        [0.2994464 ],
#        [0.28887771],
#        [0.1751384 ],
#        [0.08907901],
#        [0.17262204],
#        [0.35681933],
#        [0.32008052],
#        [0.57876195],
#        [0.57372924],
#        [0.19677906],
#        [0.20885757],
#        [0.16708606],
#        [0.13537997],
#        [0.09511827],
#        [0.11071968],
#        [0.14695521],
#        [0.11222949],
#        [0.15651736],
#        [0.17664821],
#        [0.16356316],
#        [0.17916457],
#        [0.21640664],
#        [0.20130851],
#        [0.19224962],
#        [0.19526925],
#        [0.19677906],
#        [0.14947157],
#        [0.20432813],
#        [0.60090589],
#        [0.46955209],
#        [0.41469552],
#        [0.33115249],
#        [0.29139406],
#        [0.16305989],
#        [0.03875189],
#        [0.15802718],
#        [0.41670861],
#        [0.33668848],
#        [0.6129844 ],
#        [0.50931052],
#        [0.27981882],
#        [0.27629592],
#        [0.22194263],
#        [0.1454454 ],
#        [0.08807247],
#        [0.218923  ],
#        [0.26069451],
#        [0.26220433],
#        [0.26421741],
#        [0.28183191],
#        [0.18117765],
#        [0.11122295],
#        [0.18621037],
#        [0.29038752],
#        [0.32410669],
#        [0.29290388],
#        [0.26774031],
#        [0.23553095],
#        [0.61499748],
#        [0.43935581],
#        [0.44287871],
#        [0.37745345],
#        [0.31051837],
#        [0.19728234],
#        [0.        ],
#        [0.19426271],
#        [0.37091092],
#        [0.32511324],
#        [0.58782084],
#        [0.48364368],
#        [0.39305486],
#        [0.4046301 ],
#        [0.41419225],
#        [0.44640161],
#        [0.42677403],
#        [0.39708103],
#        [0.37745345],
#        [0.32410669],
#        [0.35329643],
#        [0.42476095],
#        [0.46502265],
#        [0.44237544],
#        [0.40312028],
#        [0.43532964],
#        [0.53296427],
#        [0.49421238],
#        [0.4710619 ],
#        [0.50327126],
#        [0.61197786],
#        [0.63512833],
#        [0.38198289],
#        [0.47357826],
#        [0.37695018],
#        [0.26472068],
#        [0.24358329],
#        [0.01610468],
#        [0.248616  ],
#        [0.30951183],
#        [0.3467539 ],
#        [0.54604932],
#        [0.45143432],
#        [0.60291897],
#        [0.57322597],
#        [0.51736286],
#        [0.54403624],
#        [0.6024157 ],
#        [0.55259185],
#        [0.46250629],
#        [0.50125818],
#        [0.50931052],
#        [0.49622547],
#        [0.47508807],
#        [0.50729743],
#        [0.50880725],
#        [0.53447408],
#        [0.55007549],
#        [0.53296427],
#        [0.55460493],
#        [0.59335682],
#        [0.54353296],
#        [0.44640161],
#        [0.36336185],
#        [0.29290388],
#        [0.19124308],
#        [0.22697534],
#        [0.04630096],
#        [0.27679919],
#        [0.26874685],
#        [0.343231  ],
#        [0.562154  ],
#        [0.46149975],
#        [0.41872169],
#        [0.46703573],
#        [0.52994464],
#        [0.59235028],
#        [0.62707599],
#        [0.60493206],
#        [0.62757927],
#        [0.57171616],
#        [0.62959235],
#        [0.58983392],
#        [0.51987921],
#        [0.41368898]])

# %%
n_input = 2
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
n_input = 7
n_features = 1
train_generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
model = Sequential()

model.add(LSTM(150, activation='relu', input_shape = (n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 150)               91200
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 91,351
# Trainable params: 91,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit_generator(train_generator, epochs = 150)
# Out:
# Epoch 1/150
# 352/352 [==============================] - 5s 13ms/step - loss: 0.0275
# Epoch 2/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0224
# Epoch 3/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0196
# Epoch 4/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0181
# Epoch 5/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0168
# Epoch 6/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0163
# Epoch 7/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0155
# Epoch 8/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0151
# Epoch 9/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0152
# Epoch 10/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0151
# Epoch 11/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0149
# Epoch 12/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0151
# Epoch 13/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0148
# Epoch 14/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0145
# Epoch 15/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0147
# Epoch 16/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0140
# Epoch 17/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0144
# Epoch 18/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0145
# Epoch 19/150
# 352/352 [==============================] - 4s 11ms/step - loss: 0.0139
# Epoch 20/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0136
# Epoch 21/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0134
# Epoch 22/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0133
# Epoch 23/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0131
# Epoch 24/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0130
# Epoch 25/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0132
# Epoch 26/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0128
# Epoch 27/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0126
# Epoch 28/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0126
# Epoch 29/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0123
# Epoch 30/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0124
# Epoch 31/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0118
# Epoch 32/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0121
# Epoch 33/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0119
# Epoch 34/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0121
# Epoch 35/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0119
# Epoch 36/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0114
# Epoch 37/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0116
# Epoch 38/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0112
# Epoch 39/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0111
# Epoch 40/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0117
# Epoch 41/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0112
# Epoch 42/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0112
# Epoch 43/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0110
# Epoch 44/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0110
# Epoch 45/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0106
# Epoch 46/150
# 352/352 [==============================] - 4s 11ms/step - loss: 0.0105
# Epoch 47/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0105
# Epoch 48/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0103
# Epoch 49/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0104
# Epoch 50/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0102
# Epoch 51/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0098
# Epoch 52/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0100
# Epoch 53/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0102
# Epoch 54/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0097
# Epoch 55/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0098
# Epoch 56/150
# 352/352 [==============================] - 4s 12ms/step - loss: 0.0096
# Epoch 57/150
# 352/352 [==============================] - 5s 13ms/step - loss: 0.0100
# Epoch 58/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0092
# Epoch 59/150
# 352/352 [==============================] - 4s 12ms/step - loss: 0.0092: 0s - loss:
# Epoch 60/150
# 352/352 [==============================] - 4s 11ms/step - loss: 0.0093
# Epoch 61/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0091
# Epoch 62/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0087
# Epoch 63/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0088
# Epoch 64/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0088
# Epoch 65/150
# 352/352 [==============================] - 4s 11ms/step - loss: 0.0087
# Epoch 66/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0085
# Epoch 67/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0087
# Epoch 68/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0085
# Epoch 69/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0080
# Epoch 70/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0082
# Epoch 71/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0081
# Epoch 72/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0082
# Epoch 73/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0080
# Epoch 74/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0078
# Epoch 75/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0082
# Epoch 76/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0074
# Epoch 77/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0076
# Epoch 78/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0080
# Epoch 79/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0078
# Epoch 80/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0076
# Epoch 81/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0073
# Epoch 82/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0073
# Epoch 83/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0076
# Epoch 84/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0071
# Epoch 85/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0068
# Epoch 86/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0073
# Epoch 87/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0071
# Epoch 88/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0068
# Epoch 89/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0067
# Epoch 90/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0076
# Epoch 91/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0070
# Epoch 92/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0070
# Epoch 93/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0067
# Epoch 94/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0067
# Epoch 95/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0063
# Epoch 96/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0068
# Epoch 97/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0066
# Epoch 98/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0062
# Epoch 99/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0062
# Epoch 100/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0062
# Epoch 101/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0060
# Epoch 102/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0060
# Epoch 103/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0065
# Epoch 104/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0059
# Epoch 105/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0061
# Epoch 106/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0057
# Epoch 107/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0057
# Epoch 108/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0057
# Epoch 109/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0057
# Epoch 110/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0054
# Epoch 111/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0056
# Epoch 112/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0055
# Epoch 113/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0055
# Epoch 114/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0053
# Epoch 115/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0049
# Epoch 116/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0054
# Epoch 117/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0050
# Epoch 118/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0048
# Epoch 119/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0047
# Epoch 120/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0048
# Epoch 121/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0053
# Epoch 122/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0051
# Epoch 123/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0046
# Epoch 124/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0046
# Epoch 125/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0051
# Epoch 126/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0050
# Epoch 127/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0042
# Epoch 128/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0053
# Epoch 129/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0054
# Epoch 130/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0040
# Epoch 131/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0043
# Epoch 132/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0047
# Epoch 133/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0043
# Epoch 134/150
# 352/352 [==============================] - 3s 9ms/step - loss: 0.0039
# Epoch 135/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0041
# Epoch 136/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0039
# Epoch 137/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0047
# Epoch 138/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0050
# Epoch 139/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0044
# Epoch 140/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0044
# Epoch 141/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0037
# Epoch 142/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0039
# Epoch 143/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0042
# Epoch 144/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0038
# Epoch 145/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0036
# Epoch 146/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0033
# Epoch 147/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0037
# Epoch 148/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0037
# Epoch 149/150
# 352/352 [==============================] - 3s 10ms/step - loss: 0.0037
# Epoch 150/150
# 352/352 [==============================] - 4s 10ms/step - loss: 0.0034

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
first_eval_batch = scaled_train[-7:]

# %%
first_eval_batch
# Out:
# array([[0.60493206],
#        [0.62757927],
#        [0.57171616],
#        [0.62959235],
#        [0.58983392],
#        [0.51987921],
#        [0.41368898]])

# %%
first_eval_batch = first_eval_batch.reshape((1,n_input, n_features))

# %%
model.predict(first_eval_batch)
# Out:
# array([[0.3923865]], dtype=float32)

# %%
#forecast
#holding prediction
test_prediction = []

#last n input points from the training set
first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1,n_input, n_features))

for i in range(len(test)):
    
    current_pred = model.predict(current_batch)[0]
    test_prediction.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis = 1)

# %%
true_predictions = scaler.inverse_transform(test_prediction)

# %%
true_predictions
# Out:
# array([[948.57671968],
#        [948.91009483],
#        [948.70629997],
#        [948.86425597],
#        [949.38517322],
#        [950.52061712],
#        [951.53043052]])

# %%
test['Predictions'] = true_predictions
# Out:
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test
# Out:
#                 AP  Predictions
# period
# 2016-12-25  949.56   948.576720
# 2016-12-26  951.32   948.910095
# 2016-12-27  951.76   948.706300
# 2016-12-28  951.48   948.864256
# 2016-12-29  952.10   949.385173
# 2016-12-30  952.25   950.520617
# 2016-12-31  951.45   951.530431

# %%
test.plot(figsize=(12,8))
